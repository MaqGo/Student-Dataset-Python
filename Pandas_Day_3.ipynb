# %% [markdown]
# <a href="https://colab.research.google.com/github/MaqGo/Student-Dataset-Python/blob/main/Pandas_Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# **CREATING DATAFRAMES**

# %%
data = {"calories":[420, 380, 390],
        "duration": [50, 40, 45]}
# this is a dictionary

# %%
# Use DatFrame function to convert this dict to DataFrame
df = pd.DataFrame(data)

# assign it to df
#df is shorthand for DataFrame

# %%
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
mylist = [420, 380, 390]

# %% [markdown]
# # New section

# %%
df = pd.read_excel('student - Copy.xlsx')

# %% [markdown]
# EXPLARATORY DATA ANALYSIS (EDA)

# %%
df.head()
# return first 5 rows
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.head(2)
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male

# %%
df. tail()
# Out:
#     id         name  class  mark  gender
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
df. tail(9)
# Out:
#     id         name  class  mark  gender
# 26  27          NaN  Three    81     NaN
# 27  28    Rojj Base  Seven    86  female
# 28  29  Tess Played  Seven    55    male
# 29  30    Reppy Red    Six    79  female
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
df. sample()
# Out:
#     id       name  class  mark  gender
# 27  28  Rojj Base  Seven    86  female

# %%
df.shape
# number of rows, number of columns
# Out:
# (35, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    34 non-null     object
#  2   class   34 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  33 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df.describe()
# stastistical summary of data
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
len(df)
# number of rows
# Out:
# 35

# %%
# rows * columns
# 35 * 5
df.size
# Out:
# 175

# %%
# datatypes of the columns. Object means string. # if std is very close or bigger than mean, there are outliers
df.dtypes
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender    object
# dtype: object

# %%
# Counts missing values per column.

df.isnull().sum()
# Out:
# id        0
# name      1
# class     1
# mark      0
# gender    2
# dtype: int64

# %%
# Counts duplicate rows.
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#slicing method
df["name"]
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26            NaN
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, dtype: object

# %%
df[['gender', 'class']]
# Out:
#     gender  class
# 0   female   Four
# 1     male  Three
# 2     male  Three
# 3   female   Four
# 4   female   Four
# 5     male   Four
# 6     male  Fifth
# 7     male   Five
# 8      NaN    Six
# 9   female   Four
# 10  female    Six
# 11  female    Six
# 12  female  Seven
# 13  female  Seven
# 14    male    NaN
# 15    male   Four
# 16    male    Six
# 17    male   Five
# 18    male   Nine
# 19  female   Nine
# 20  female   Four
# 21  female  Seven
# 22    male  Eight
# 23    male  Seven
# 24    male  Seven
# 25    male  Seven
# 26     NaN  Three
# 27  female  Seven
# 28    male  Seven
# 29  female    Six
# 30    male   Four
# 31  female  Seven
# 32  female    Six
# 33    male  Seven
# 34  female    Six

# %%
df[["name", "id"]].sample(3)
# Out:
#      name  id
# 11  Recky  12
# 17  Honny  18
# 16  Tumyu  17

# %%
# df.loc[rows , columns names]
df.loc[0:2, ["name", "gender"]]
# Out:
#        name  gender
# 0  John Deo  female
# 1  Max Ruin    male
# 2    Arnold    male

# %%
df.loc[0, "name"]
# name of the first student
# Out:
# 'John Deo'

# %%
df.loc[0, "class"]
# class of the first student
# Out:
# 'Four'

# %%
df.loc[0:4, ['id', 'name']]
# Out:
#    id        name
# 0   1    John Deo
# 1   2    Max Ruin
# 2   3      Arnold
# 3   4  Krish Star
# 4   5   John Mike

# %%
df.loc[:4, ['id', 'name']]
# 0:4 range from index 0 to index 4
# if you omit starting index, it will start from the beginning
# Out:
#    id        name
# 0   1    John Deo
# 1   2    Max Ruin
# 2   3      Arnold
# 3   4  Krish Star
# 4   5   John Mike

# %% [markdown]
# Filtering data

# %%
# df[condition]
# Mark greater than 90
df [df["mark"]>90]
# this code will return only true
# Out:
#     id       name class  mark  gender
# 11  12      Recky   Six    94  female
# 32  33  Kenn Rein   Six    96  female

# %%
df[df["class"]=="Four"]
# Out:
#     id         name class  mark  gender
# 0    1     John Deo  Four    75  female
# 3    4   Krish Star  Four    60  female
# 4    5    John Mike  Four    60  female
# 5    6    Alex John  Four    55    male
# 9   10     Big John  Four    55  female
# 15  16        Gimmy  Four    88    male
# 20  21   Babby John  Four    69  female
# 30  31  Marry Toeey  Four    88    male

# %%
df[df["class"]=="Four"][["name", "class", "gender"]]
# Out:
#            name class  gender
# 0      John Deo  Four  female
# 3    Krish Star  Four  female
# 4     John Mike  Four  female
# 5     Alex John  Four    male
# 9      Big John  Four  female
# 15        Gimmy  Four    male
# 20   Babby John  Four  female
# 30  Marry Toeey  Four    male

# %%
df.loc[df["class"]=="Four", ["name", "class", "gender"]]
# Out:
#            name class  gender
# 0      John Deo  Four  female
# 3    Krish Star  Four  female
# 4     John Mike  Four  female
# 5     Alex John  Four    male
# 9      Big John  Four  female
# 15        Gimmy  Four    male
# 20   Babby John  Four  female
# 30  Marry Toeey  Four    male

# %%
df.iloc[:, [df.columns.get_loc("name"), df.columns.get_loc("class"), df.columns.get_loc("gender")]]
# Out:
#            name  class  gender
# 0      John Deo   Four  female
# 1      Max Ruin  Three    male
# 2        Arnold  Three    male
# 3    Krish Star   Four  female
# 4     John Mike   Four  female
# 5     Alex John   Four    male
# 6   My John Rob  Fifth    male
# 7        Asruid   Five    male
# 8       Tes Qry    Six     NaN
# 9      Big John   Four  female
# 10       Ronald    Six  female
# 11        Recky    Six  female
# 12          Kty  Seven  female
# 13         Bigy  Seven  female
# 14     Tade Row    NaN    male
# 15        Gimmy   Four    male
# 16        Tumyu    Six    male
# 17        Honny   Five    male
# 18        Tinny   Nine    male
# 19       Jackly   Nine  female
# 20   Babby John   Four  female
# 21       Reggid  Seven  female
# 22        Herod  Eight    male
# 23    Tiddy Now  Seven    male
# 24     Giff Tow  Seven    male
# 25       Crelea  Seven    male
# 26          NaN  Three     NaN
# 27    Rojj Base  Seven  female
# 28  Tess Played  Seven    male
# 29    Reppy Red    Six  female
# 30  Marry Toeey   Four    male
# 31    Binn Rott  Seven  female
# 32    Kenn Rein    Six  female
# 33     Gain Toe  Seven    male
# 34   Rows Noump    Six  female

# %%
df[df["class"] == "Four"].iloc[:, [df.columns.get_loc("name"), df.columns.get_loc("class"), df.columns.get_loc("gender")]]
# Out:
#            name class  gender
# 0      John Deo  Four  female
# 3    Krish Star  Four  female
# 4     John Mike  Four  female
# 5     Alex John  Four    male
# 9      Big John  Four  female
# 15        Gimmy  Four    male
# 20   Babby John  Four  female
# 30  Marry Toeey  Four    male

# %%
df[(df["class"]=="Four") & (df["gender"]=="male")]
# Out:
#     id         name class  mark gender
# 5    6    Alex John  Four    55   male
# 15  16        Gimmy  Four    88   male
# 30  31  Marry Toeey  Four    88   male

# %%
df [(df["gender"]=="female") & (df["mark"] < 70)]
# Out:
#     id        name  class  mark  gender
# 3    4  Krish Star   Four    60  female
# 4    5   John Mike   Four    60  female
# 9   10    Big John   Four    55  female
# 19  20      Jackly   Nine    65  female
# 20  21  Babby John   Four    69  female
# 21  22      Reggid  Seven    55  female
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4['id'].plot(kind='hist', bins=20, title='id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5['mark'].plot(kind='hist', bins=20, title='mark')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('class').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='index', y='id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='id', y='mark', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['mark']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('mark')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['mark']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('class')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='class', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('mark')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('class')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='class', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['id'].plot(kind='line', figsize=(8, 4), title='id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['mark'].plot(kind='line', figsize=(8, 4), title='mark')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['class'].value_counts()
#     for x_label, grp in _df_17.groupby('name')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('name')
# _ = plt.ylabel('class')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='index', y='name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['class'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='index', y='class', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='id', y='name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['class'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='id', y='class', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.loc[(df["mark"]<70) & (df["gender"]=="female"),["name", "class"]]
# Out:
#           name  class
# 3   Krish Star   Four
# 4    John Mike   Four
# 9     Big John   Four
# 19      Jackly   Nine
# 20  Babby John   Four
# 21      Reggid  Seven

# %%
df.sort_values(by="name")
# Out:
#     id         name  class  mark  gender
# 5    6    Alex John   Four    55    male
# 2    3       Arnold  Three    55    male
# 7    8       Asruid   Five    85    male
# 20  21   Babby John   Four    69  female
# 9   10     Big John   Four    55  female
# 13  14         Bigy  Seven    88  female
# 31  32    Binn Rott  Seven    90  female
# 25  26       Crelea  Seven    79    male
# 33  34     Gain Toe  Seven    69    male
# 24  25     Giff Tow  Seven    88    male
# 15  16        Gimmy   Four    88    male
# 22  23        Herod  Eight    79    male
# 17  18        Honny   Five    75    male
# 19  20       Jackly   Nine    65  female
# 0    1     John Deo   Four    75  female
# 4    5    John Mike   Four    60  female
# 32  33    Kenn Rein    Six    96  female
# 3    4   Krish Star   Four    60  female
# 12  13          Kty  Seven    88  female
# 30  31  Marry Toeey   Four    88    male
# 1    2     Max Ruin  Three    85    male
# 6    7  My John Rob  Fifth    78    male
# 11  12        Recky    Six    94  female
# 21  22       Reggid  Seven    55  female
# 29  30    Reppy Red    Six    79  female
# 27  28    Rojj Base  Seven    86  female
# 10  11       Ronald    Six    89  female
# 34  35   Rows Noump    Six    88  female
# 14  15     Tade Row    NaN    88    male
# 8    9      Tes Qry    Six    78     NaN
# 28  29  Tess Played  Seven    55    male
# 23  24    Tiddy Now  Seven    78    male
# 18  19        Tinny   Nine    18    male
# 16  17        Tumyu    Six    54    male
# 26  27          NaN  Three    81     NaN

# %%
df.sort_values(by="mark")
# Out:
#     id         name  class  mark  gender
# 18  19        Tinny   Nine    18    male
# 16  17        Tumyu    Six    54    male
# 2    3       Arnold  Three    55    male
# 5    6    Alex John   Four    55    male
# 28  29  Tess Played  Seven    55    male
# 21  22       Reggid  Seven    55  female
# 9   10     Big John   Four    55  female
# 4    5    John Mike   Four    60  female
# 3    4   Krish Star   Four    60  female
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 33  34     Gain Toe  Seven    69    male
# 0    1     John Deo   Four    75  female
# 17  18        Honny   Five    75    male
# 8    9      Tes Qry    Six    78     NaN
# 23  24    Tiddy Now  Seven    78    male
# 6    7  My John Rob  Fifth    78    male
# 22  23        Herod  Eight    79    male
# 29  30    Reppy Red    Six    79  female
# 25  26       Crelea  Seven    79    male
# 26  27          NaN  Three    81     NaN
# 1    2     Max Ruin  Three    85    male
# 7    8       Asruid   Five    85    male
# 27  28    Rojj Base  Seven    86  female
# 12  13          Kty  Seven    88  female
# 24  25     Giff Tow  Seven    88    male
# 15  16        Gimmy   Four    88    male
# 14  15     Tade Row    NaN    88    male
# 30  31  Marry Toeey   Four    88    male
# 13  14         Bigy  Seven    88  female
# 34  35   Rows Noump    Six    88  female
# 10  11       Ronald    Six    89  female
# 31  32    Binn Rott  Seven    90  female
# 11  12        Recky    Six    94  female
# 32  33    Kenn Rein    Six    96  female

# %%
df.sort_values(by="mark").head()
# ascending order
# Out:
#     id         name  class  mark gender
# 18  19        Tinny   Nine    18   male
# 16  17        Tumyu    Six    54   male
# 2    3       Arnold  Three    55   male
# 5    6    Alex John   Four    55   male
# 28  29  Tess Played  Seven    55   male

# %%
df.sort_values(by="name", ascending=False).head(10)
# descending order
# ascending false will reverse the order. its in descending order
# Out:
#     id         name  class  mark  gender
# 16  17        Tumyu    Six    54    male
# 18  19        Tinny   Nine    18    male
# 23  24    Tiddy Now  Seven    78    male
# 28  29  Tess Played  Seven    55    male
# 8    9      Tes Qry    Six    78     NaN
# 14  15     Tade Row    NaN    88    male
# 34  35   Rows Noump    Six    88  female
# 10  11       Ronald    Six    89  female
# 27  28    Rojj Base  Seven    86  female
# 29  30    Reppy Red    Six    79  female

# %%
df.sort_values(by="mark", ascending=False).head()
# descending order
# Out:
#     id         name  class  mark  gender
# 32  33    Kenn Rein    Six    96  female
# 11  12        Recky    Six    94  female
# 31  32    Binn Rott  Seven    90  female
# 10  11       Ronald    Six    89  female
# 30  31  Marry Toeey   Four    88    male

# %%
# applyting sort after slicing
df[df["class"]=="Six"].sort_values(by="mark")
# Out:
#     id        name class  mark  gender
# 16  17       Tumyu   Six    54    male
# 8    9     Tes Qry   Six    78     NaN
# 29  30   Reppy Red   Six    79  female
# 34  35  Rows Noump   Six    88  female
# 10  11      Ronald   Six    89  female
# 11  12       Recky   Six    94  female
# 32  33   Kenn Rein   Six    96  female

# %%
df.loc[df["class"]=="Six", :].sort_values(by="mark")
# Out:
#     id        name class  mark  gender
# 16  17       Tumyu   Six    54    male
# 8    9     Tes Qry   Six    78     NaN
# 29  30   Reppy Red   Six    79  female
# 34  35  Rows Noump   Six    88  female
# 10  11      Ronald   Six    89  female
# 11  12       Recky   Six    94  female
# 32  33   Kenn Rein   Six    96  female

# %%
df["mark"] . mean ()
# Out:
# np.float64(74.65714285714286)

# %%
df[(df["gender"] == "female") & (df["mark"] > df["mark"].mean())].sort_values(by="mark", ascending=False)
# Out:
#     id        name  class  mark  gender
# 32  33   Kenn Rein    Six    96  female
# 11  12       Recky    Six    94  female
# 31  32   Binn Rott  Seven    90  female
# 10  11      Ronald    Six    89  female
# 34  35  Rows Noump    Six    88  female
# 12  13         Kty  Seven    88  female
# 13  14        Bigy  Seven    88  female
# 27  28   Rojj Base  Seven    86  female
# 29  30   Reppy Red    Six    79  female
# 0    1    John Deo   Four    75  female

# %%
## How many male and female students are there?
df["gender"].value_counts()
# Out:
# gender
# male      17
# female    16
# Name: count, dtype: int64

# %%
# how many student in each class
df["class"].value_counts()
# Out:
# class
# Seven    10
# Four      8
# Six       7
# Three     3
# Nine      2
# Five      2
# Fifth     1
# Eight     1
# Name: count, dtype: int64
